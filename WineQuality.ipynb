# %%
import pandas as pd
dat= pd.read_csv(r"C:\Users\HP\OneDrive\Documents\WineQT.csv")
dat
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# # 1) Which pH value is most frequent

# %%
print("Total number of wine tested:", len(data))
print("pH values of the samples")
print(dat["pH"].value_counts())
# Out:
# Total number of wine tested: 1143
# pH values of the samples
# 3.30    41
# 3.36    40
# 3.38    38
# 3.39    37
# 3.26    33
#         ..
# 2.86     1
# 2.95     1
# 2.74     1
# 3.75     1
# 2.90     1
# Name: pH, Length: 87, dtype: int64

# %% [markdown]
# # 2. Values of Chloride (seaborn)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,12))
sns.countplot(x="chlorides",data=dat)
plt.title("Values of Chloride present")
# Out:
# Text(0.5, 1.0, 'Values of Chloride present')

# %% [markdown]
# # 3. Plotting fixed and volatile acidity values (histogram)

# %%
import numpy as p
import matplotlib.pyplot as plt
xvalues=dat["fixed acidity"]
yvalues=dat["volatile acidity"]
plt.bar(xvalues,yvalues)
plt.title("Comparison of fixed and volatile acidity")
plt.xlabel("value of fixed acidity")
plt.ylabel("value of volatile acidity")
plt.show()

# %% [markdown]
# # 4. Range of alcohol values (using seaborn)

# %%
import seaborn as sns
sns.countplot(x="alcohol",data=dat)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='count'>

# %% [markdown]
# # 5. Values of the wine quality (using pie chart)

# %%
import matplotlib.pyplot as plt
values=dat["quality"].value_counts()
label=("3","4","5","6","7","8")
plt.pie(values,labels=label,autopct="%0.2f%%")
plt.title("Range of quality among the samples")
plt.show()

# %% [markdown]
# # 6.Give the correlation of the data

# %%
import seaborn as sns
sns.heatmap(dat.corr(),cmap='coolwarm',annot=True,linecolor='white',linewidths=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 7. Mean of free and total sulfur dioxide (bar chart)

# %%
t=[]
t.append(dat["free sulfur dioxide"].mean())
t.append(dat["total sulfur dioxide"].mean())
t
import numpy as np
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(5,10))
xvalues=[1,2]
yvalues=t

plt.bar(xvalues,yvalues[0:20],tick_label=["free sulfur dioxide","total sulfur dioxide"],width=0.4)
plt.show()

# %% [markdown]
# # 8. plotting Id and residual sugar values (simple plot)

# %%
import matplotlib.pyplot as plt
x=dat["Id"]
y=dat["residual sugar"]
plt.plot(x,y)
plt.show()

# %% [markdown]
# # 9. Plotting Id and Citric Acid Values (scatter plot)

# %%
import matplotlib.pyplot as plt
x=dat["Id"]
y=dat["citric acid"]
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # 10. Description of Sulphate values

# %%
dat['sulphates'].describe()
# Out:
# count    1143.000000
# mean        0.657708
# std         0.170399
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %% [markdown]
# # 11. Returning top 5 values of 3 columns

# %%
samples= dat[['Id','density','quality']]
samples.head()
# Out:
#    Id  density  quality
# 0   0   0.9978        5
# 1   1   0.9968        5
# 2   2   0.9970        5
# 3   3   0.9980        6
# 4   4   0.9978        5
